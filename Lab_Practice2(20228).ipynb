# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
link='/content/drive/MyDrive/test1.csv'
data=pd.read_csv(link)
data
# Out:
#        Unnamed: 0  39          State-gov   77516    Bachelors  13  \
# 0               0  50   Self-emp-not-inc   83311    Bachelors  13
# 1               1  38            Private  215646      HS-grad   9
# 2               2  53            Private  234721         11th   7
# 3               3  28            Private  338409    Bachelors  13
# 4               4  37            Private  284582      Masters  14
# ...           ...  ..                ...     ...          ...  ..
# 32555       32555  27            Private  257302   Assoc-acdm  12
# 32556       32556  40            Private  154374      HS-grad   9
# 32557       32557  58            Private  151910      HS-grad   9
# 32558       32558  22            Private  201490      HS-grad   9
# 32559       32559  52       Self-emp-inc  287927      HS-grad   9
#
#              Never-married        Adm-clerical   Not-in-family   White  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0            39         77516            13          2174  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000  32560.000000
# mean   16279.500000     38.581634  1.897818e+05     10.080590   1077.615172
# std     9399.406719     13.640642  1.055498e+05      2.572709   7385.402999
# min        0.000000     17.000000  1.228500e+04      1.000000      0.000000
# 25%     8139.750000     28.000000  1.178315e+05      9.000000      0.000000
# 50%    16279.500000     37.000000  1.783630e+05     10.000000      0.000000
# 75%    24419.250000     48.000000  2.370545e+05     12.000000      0.000000
# max    32559.000000     90.000000  1.484705e+06     16.000000  99999.000000
#
#                   0            40
# count  32560.000000  32560.000000
# mean      87.306511     40.437469
# std      402.966116     12.347618
# min        0.000000      1.000000
# 25%        0.000000     40.000000
# 50%        0.000000     40.000000
# 75%        0.000000     45.000000
# ...

# %%
list(data)
# Out:
# ['age',
#  'type_employer',
#  'fnlwgt',
#  'education',
#  'education_num',
#  'marital',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital_gain',
#  'capital_loss',
#  'hr_per_week',
#  'country',
#  'income']

# %%
data.head(3)
# Out:
#    Unnamed: 0  39          State-gov   77516   Bachelors  13  \
# 0           0  50   Self-emp-not-inc   83311   Bachelors  13
# 1           1  38            Private  215646     HS-grad   9
# 2           2  53            Private  234721        11th   7
#
#          Never-married        Adm-clerical   Not-in-family   White   Male  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    2174  0  40   United-States   <=50K
# 0     0  0  13   United-States   <=50K
# 1     0  0  40   United-States   <=50K
# 2     0  0  40   United-States   <=50K

# %%
data.tail(4)
# Out:
#        Unnamed: 0  39      State-gov   77516  Bachelors  13  \
# 32556       32556  40        Private  154374    HS-grad   9
# 32557       32557  58        Private  151910    HS-grad   9
# 32558       32558  22        Private  201490    HS-grad   9
# 32559       32559  52   Self-emp-inc  287927    HS-grad   9
#
#              Never-married        Adm-clerical  Not-in-family   White  \
# 32556   Married-civ-spouse   Machine-op-inspct        Husband   White
# 32557              Widowed        Adm-clerical      Unmarried   White
# 32558        Never-married        Adm-clerical      Own-child   White
# 32559   Married-civ-spouse     Exec-managerial           Wife   White
#
#           Male   2174  0  40   United-States   <=50K
# 32556     Male      0  0  40   United-States    >50K
# 32557   Female      0  0  40   United-States   <=50K
# 32558     Male      0  0  20   United-States   <=50K
# 32559   Female  15024  0  40   United-States    >50K

# %%
print(data.iloc[264])
# Out:
# Unnamed: 0                        264
# 39                                 37
#  State-gov               Self-emp-inc
# 77516                          257295
#  Bachelors               Some-college
# 13                                 10
#  Never-married     Married-civ-spouse
#  Adm-clerical         Exec-managerial
#  Not-in-family                Husband
#  White             Asian-Pac-Islander
#  Male                            Male
# 2174                                0
# 0                                   0
# 40                                 75
#  United-States               Thailand
#  <=50K                           >50K
# Name: 264, dtype: object

# %%
data.rename(columns = {' <=50K':'Income'})
# Out:
#        Unnamed: 0  39          State-gov   77516    Bachelors  13  \
# 0               0  50   Self-emp-not-inc   83311    Bachelors  13
# 1               1  38            Private  215646      HS-grad   9
# 2               2  53            Private  234721         11th   7
# 3               3  28            Private  338409    Bachelors  13
# 4               4  37            Private  284582      Masters  14
# ...           ...  ..                ...     ...          ...  ..
# 32555       32555  27            Private  257302   Assoc-acdm  12
# 32556       32556  40            Private  154374      HS-grad   9
# 32557       32557  58            Private  151910      HS-grad   9
# 32558       32558  22            Private  201490      HS-grad   9
# 32559       32559  52       Self-emp-inc  287927      HS-grad   9
#
#              Never-married        Adm-clerical   Not-in-family   White  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '39', ' State-gov', '77516', ' Bachelors', '13',
#        ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', ' Male',
#        '2174', '0', '40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
data
# Out:
#        Unnamed: 0  39          State-gov   77516    Bachelors  13  \
# 0               0  50   Self-emp-not-inc   83311    Bachelors  13
# 1               1  38            Private  215646      HS-grad   9
# 2               2  53            Private  234721         11th   7
# 3               3  28            Private  338409    Bachelors  13
# 4               4  37            Private  284582      Masters  14
# ...           ...  ..                ...     ...          ...  ..
# 32555       32555  27            Private  257302   Assoc-acdm  12
# 32556       32556  40            Private  154374      HS-grad   9
# 32557       32557  58            Private  151910      HS-grad   9
# 32558       32558  22            Private  201490      HS-grad   9
# 32559       32559  52       Self-emp-inc  287927      HS-grad   9
#
#              Never-married        Adm-clerical   Not-in-family   White  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.columns = ['age', 'type_employer', 'fnlwgt','education', 'education_num', 'marital','occupation','relationship', 'race','sex', 'capital_gain', 'capital_loss','hr_per_week', 'country', 'income']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-9e71eaa17e78> in <module>
# ----> 1 data.columns = ['age', 'type_employer', 'fnlwgt','education', 'education_num', 'marital','occupation','relationship', 'race','sex', 'capital_gain', 'capital_loss','hr_per_week', 'country', 'income']
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
list(data)
# Out:
# ['age',
#  'type_employer',
#  'fnlwgt',
#  'education',
#  'education_num',
#  'marital',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital_gain',
#  'capital_loss',
#  'hr_per_week',
#  'country',
#  'income']

# %%
data.iloc[0:9,10:14]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-342edee11926> in <module>
# ----> 1 data.iloc[0:9,10:14]
#
# NameError: name 'data' is not defined

# %%
data.iloc['264']['<=50k']=='>50k'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-cd3ba069c4c9> in <module>
# ----> 1 data.iloc['264']['<=50k']=='>50k'
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1561             key = item_from_zerodim(key)
#    1562             if not is_integer(key):
# -> 1563                 raise TypeError("Cannot index by location index with a non-integer key")
#    1564
#    1565             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key
