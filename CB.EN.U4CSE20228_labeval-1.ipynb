# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **q1**

# %%
df28=pd.read_csv('/content/IoTBotNetDataset.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# **q2**

# %%
df28= pd.DataFrame(df28)
df28.drop(['pkSeqID'], axis=1)
# Out:
#                stime flags  flgs_number proto  proto_number            saddr  \
# 0       1.528089e+09     e          1.0   tcp           1.0  192.168.100.147
# 1       1.528089e+09     e          1.0   arp           2.0    192.168.100.7
# 2       1.528089e+09     e          1.0   UDP           1.0  192.168.100.147
# 3       1.528089e+09     i          1.0   tcp           1.0  192.168.100.147
# 4       1.528089e+09     e          1.0   UDP           1.0  192.168.100.147
# ...              ...   ...          ...   ...           ...              ...
# 998548  1.528085e+09     e          1.0   udp           3.0  192.168.100.149
# 998549  1.528085e+09     e          1.0   udp           3.0  192.168.100.149
# 998550  1.528085e+09     e          1.0   udp           3.0  192.168.100.149
# 998551  1.528085e+09     e          1.0   udp           3.0  192.168.100.149
# 998552  1.528085e+09     e          1.0   udp           3.0  192.168.100.149
#
# ...

# %% [markdown]
# **q3**

# %%
df28.isnull()
df28.fillna(0)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport            daddr dport  ...  \
# 0       192.168.100.147  49960    192.168.100.7    80  ...
# ...

# %% [markdown]
# **q4**

# %%
df28.plot.box() 
plt.boxplot(df28['pkts']) 
plt.show()
plt.boxplot(df28['spkts']) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# **q5**

# %%
 print(df28['rate'].corr(df['srate']))
# Out:
# 0.18904714981030551

# %% [markdown]
# **q6**

# %%
df28.describe()
# Out:
#              pkSeqID         stime    flgs_number   proto_number  \
# count  996297.000000  9.962970e+05  996297.000000  996294.000000
# mean   500191.103927  1.528083e+09       1.808430       1.765398
# std    287942.231266  1.754173e+03       1.107501       0.972087
# min         1.000000  1.528081e+09       1.000000       1.000000
# 25%    251331.000000  1.528081e+09       1.000000       1.000000
# 50%    500405.000000  1.528081e+09       2.000000       1.000000
# 75%    749479.000000  1.528085e+09       2.000000       3.000000
# max    998553.000000  1.528089e+09       6.000000       4.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  996297.000000  996297.000000  996297.000000  9.962970e+05
# mean        6.520403     614.684976       2.826334  1.528083e+09
# std         8.634993     605.434762       1.210459  1.752839e+03
# min         1.000000     120.000000       1.000000  1.528081e+09
# ...

# %% [markdown]
# **q7**

# %%
df28.head(3)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0      1.0  1.528089e+09     e          1.0   tcp           1.0
# 1      2.0  1.528089e+09     e          1.0   arp           2.0
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147    -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0               96.0              75.0            1.133720
# 1                1.0               2.0            0.005142
# 2               96.0              75.0            1.135100
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.129970                             770.0
# ...

# %% [markdown]
# **q8**

# %%
df28.tail(4)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_DstIP  \
# 998549  192.168.100.149  24882  192.168.100.5    80  ...            0.269102
# 998550  192.168.100.149  24883  192.168.100.5    80  ...            0.269102
# 998551  192.168.100.149  24884  192.168.100.5    80  ...            0.269102
# 998552  192.168.100.149  24885  192.168.100.5    80  ...            0.269102
#
#         N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 998549              100.0             100.0            0.269107
# 998550              100.0             100.0            0.269107
# ...

# %% [markdown]
# **q9**

# %%
df28=df28.rename(columns={ 'proto':' UDP'})
df28.columns
# Out:
# Index(['pkSeqID', 'stime', 'flags', 'flgs_number', ' UDP', 'proto_number',
#        'saddr', 'sport', 'daddr', 'dport', 'pkts', 'bytes', 'state',
#        'state_number', 'ltime', 'seq', 'dur', 'mean', 'stddev', 'sum', 'min',
#        'max', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'srate', 'drate',
#        'TnBPSrcIP', 'TnBPDstIP', 'TnP_PSrcIP', 'TnP_PDstIP', 'TnP_PerProto',
#        'TnP_Per_Dport', 'AR_P_Proto_P_SrcIP', 'AR_P_Proto_P_DstIP',
#        'N_IN_Conn_P_DstIP', 'N_IN_Conn_P_SrcIP', 'AR_P_Proto_P_Sport',
#        'AR_P_Proto_P_Dport', 'Pkts_P_State_P_Protocol_P_DestIP',
#        'Pkts_P_State_P_Protocol_P_SrcIP', 'attack', 'category', 'subcategory'],
#       dtype='object')

# %% [markdown]
# **q10**

# %%
df28.shape[0]
# Out:
# 998553

# %% [markdown]
# **q11**

# %%
df28.iloc[0][0:5]
# Out:
# pkSeqID                 1.0
# stime          1528088522.0
# flags                     e
# flgs_number             1.0
#  UDP                    tcp
# Name: 0, dtype: object

# %% [markdown]
# **q12**

# %%
df28['flags'].value_counts()
# Out:
# e s    462424
# e      450021
# e g     76063
# eU       7746
# i          30
# e d         9
# e *         4
# Name: flags, dtype: int64

# %% [markdown]
# **q13**

# %%
G1=df28.loc[df28.pkts<=10]
G1.loc[0:998553]['pkts']
# Out:
# 0         8.0
# 1         2.0
# 2         8.0
# 3         8.0
# 4         8.0
#          ...
# 998548    7.0
# 998549    7.0
# 998550    7.0
# 998551    7.0
# 998552    7.0
# Name: pkts, Length: 875049, dtype: float64

# %%
G2=df28.loc[df28.pkts>10]
G2.loc[0:998553]['pkts']
# Out:
# 144       12.0
# 276       14.0
# 277       11.0
# 278       12.0
# 283       11.0
#           ...
# 998213    13.0
# 998214    13.0
# 998215    13.0
# 998216    13.0
# 998217    13.0
# Name: pkts, Length: 121248, dtype: float64

# %% [markdown]
# **q14**

# %%
print(df28.groupby("subcategory").Pkts_P_State_P_Protocol_P_DestIP.mean())
print(df28.groupby("subcategory").Pkts_P_State_P_Protocol_P_DestIP.var())
# Out:
# subcategory
# HTTP    746.097643
# TCP     329.842411
# UDP     742.008949
# Name: Pkts_P_State_P_Protocol_P_DestIP, dtype: float64
# subcategory
# HTTP    60446.448007
# TCP     21456.481203
# UDP     89808.333377
# Name: Pkts_P_State_P_Protocol_P_DestIP, dtype: float64

# %% [markdown]
# **q15**

# %%
import seaborn as sns
sns.boxplot(df28['stime'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
